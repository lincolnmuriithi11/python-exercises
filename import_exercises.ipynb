# %%
# # from somemodule import somefunction as some_func
# from anothermodule import anotherfunction as another_func, yetanotherfunction as yaf


from function_exercises import letter_grade

print(letter_grade(70))
# Out:
# C

# %%
from function_exercises import calculate_tip
print(calculate_tip(100, 0.2))
# Out:
# 20.0

# %%
from function_exercises import is_vowel
is_vowel("e")
# Out:
# True

# %%
from function_exercises import get_letter_grade
get_letter_grade(80)
# Out:
# 'B'

# %%
import itertools 
st = "abc123"
combinations = itertools.permutations(st)
for value in combinations:
    
    print (*value)
# Out:
# a b c 1 2 3
# a b c 1 3 2
# a b c 2 1 3
# a b c 2 3 1
# a b c 3 1 2
# a b c 3 2 1
# a b 1 c 2 3
# a b 1 c 3 2
# a b 1 2 c 3
# a b 1 2 3 c
# a b 1 3 c 2
# a b 1 3 2 c
# a b 2 c 1 3
# a b 2 c 3 1
# a b 2 1 c 3
# a b 2 1 3 c
# a b 2 3 c 1
# a b 2 3 1 c
# a b 3 c 1 2
# a b 3 c 2 1
# a b 3 1 c 2
# a b 3 1 2 c
# a b 3 2 c 1
# a b 3 2 1 c
# a c b 1 2 3
# a c b 1 3 2
# a c b 2 1 3
# a c b 2 3 1
# a c b 3 1 2
# a c b 3 2 1
# a c 1 b 2 3
# a c 1 b 3 2
# a c 1 2 b 3
# a c 1 2 3 b
# a c 1 3 b 2
# a c 1 3 2 b
# a c 2 b 1 3
# a c 2 b 3 1
# a c 2 1 b 3
# a c 2 1 3 b
# a c 2 3 b 1
# a c 2 3 1 b
# a c 3 b 1 2
# a c 3 b 2 1
# a c 3 1 b 2
# a c 3 1 2 b
# a c 3 2 b 1
# a c 3 2 1 b
# a 1 b c 2 3
# a 1 b c 3 2
# a 1 b 2 c 3
# a 1 b 2 3 c
# a 1 b 3 c 2
# a 1 b 3 2 c
# a 1 c b 2 3
# a 1 c b 3 2
# a 1 c 2 b 3
# a 1 c 2 3 b
# a 1 c 3 b 2
# a 1 c 3 2 b
# a 1 2 b c 3
# a 1 2 b 3 c
# a 1 2 c b 3
# a 1 2 c 3 b
# a 1 2 3 b c
# a 1 2 3 c b
# a 1 3 b c 2
# a 1 3 b 2 c
# a 1 3 c b 2
# a 1 3 c 2 b
# a 1 3 2 b c
# ...

# %%
import itertools 
st = "abc"
two_combinations = itertools.combinations(st, 2)
for value in two_combinations:
    print (*value)
# Out:
# a b
# a c
# b c

# %%
import itertools 
st = "abc"
two_permutations = itertools.permutations(st, 2)
for value in two_permutations:
    print (*value)
# Out:
# a b
# a c
# b a
# b c
# c a
# c b
